# %%
! pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: efficientnet_pytorch in /environment/miniconda3/lib/python3.7/site-packages (0.7.1)
# Requirement already satisfied: torch in /environment/miniconda3/lib/python3.7/site-packages (from efficientnet_pytorch) (1.10.0+cu113)
# Requirement already satisfied: typing-extensions in /environment/miniconda3/lib/python3.7/site-packages (from torch->efficientnet_pytorch) (4.0.1)

# %%
from __future__ import print_function, division
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, models, transforms
import torchvision
import matplotlib.pyplot as plt
from efficientnet_pytorch import EfficientNet
import numpy as np

# %%
train_dir = './data/train_valid/train'
valid_dir = './data/train_valid/valid'

# %%
# Preprocess the data
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.08, 1.0), ratio=(3.0/4.0, 4.0/3.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

valid_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# train_transforms = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.485, 0.456, 0.406], 
#                                                             [0.229, 0.224, 0.225])])

# valid_transforms = transforms.Compose([transforms.Resize(256),
#                                        transforms.CenterCrop(224),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.485, 0.456, 0.406], 
#                                                             [0.229, 0.224, 0.225])])

# %%
# Load the datasets with ImageFolder and preprocess
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(valid_dir,transform=valid_transforms)

# Use the datasets and the transforms to define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=32, shuffle=False)

# %%
# Adjust the learning rate
def lr_scheduler(optimizer, epoch, init_lr=0.01, lr_decay_epoch=10):
    lr = init_lr * (0.8 ** (epoch // lr_decay_epoch))
    print('LR is set to {}'.format(lr))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return optimizer

# %%
use_gpu = torch.cuda.is_available()
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
num_epochs = 30

# Load the model
model_ft = EfficientNet.from_pretrained('efficientnet-b4')
# Change the classify layer
num_ftrs = model_ft._fc.in_features
model_ft._fc = nn.Linear(num_ftrs, 120)
# Use CrossEntropyLoss as the loss function
criterion = nn.CrossEntropyLoss()
# Use SGD as the optimizer
optimizer = optim.SGD((model_ft.parameters()), lr=0.01, momentum=0.9, weight_decay=0.0004)
if use_gpu:
    model_ft = model_ft.cuda()
    criterion = criterion.cuda()

print('Start Training')
total_step = len(train_loader)
best_acc = 0
model_ft.train(True)
record_train = list()
record_valid = list()
loss_record_train = list()
loss_record_valid = list()

for epoch in range(num_epochs):
    # Save the training process
    mylog = open('EfficientNet_training_progress.log', mode='a', encoding='utf-8')
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs), file=mylog)
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs))
    num_correct = 0
    num_total = 0
    
    start = time.time()
    # Adjust the learning rate
    optimizer = lr_scheduler(optimizer, epoch)
    # Initialize training loss
    train_loss = 0.0
    valid_loss = 0.0
    # Start training the model
    for i, (inputs, labels) in enumerate(train_loader):
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        # Clear the gradient
        optimizer.zero_grad()
        # Feed forward
        outputs = model_ft(inputs)
        loss = criterion(outputs, labels)
        # Back propagation
        loss.backward()
        optimizer.step()
        # Predict
        _, prediction = torch.max(outputs.data, 1)
        num_total += labels.size(0)
        num_correct += torch.sum(prediction == labels.data)
        train_acc = 100.0 * num_correct / num_total
        train_loss = train_loss + ((1 / (i + 1)) * (loss.data - train_loss)) 

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs, i + 1, total_step, train_loss, train_acc))
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs, i + 1, total_step, train_loss, train_acc), file=mylog)

    record_train.append(train_acc)
    loss_record_train.append(loss.item())
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc))
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc), file=mylog)
    print("--- cost time: {:.4f}s ---".format(time.time() - start))
    print("--- cost time: {:.4f}s ---".format(time.time() - start), file=mylog)

    # test on the validation set
    print("*************** valid ***************")
    print("*************** valid ***************", file=mylog)
    with torch.no_grad():
        num_correct = 0
        num_total = 0
        for i, (inputs, labels) in enumerate(valid_loader):
            model_ft.eval()
            inputs = torch.autograd.Variable(inputs.cuda())
            labels = torch.autograd.Variable(labels.cuda())

            outputs = model_ft(inputs)
            loss = criterion(outputs, labels)
            valid_loss += ((1 / (i + 1)) * (loss.data - valid_loss))
            _, prediction = torch.max(outputs.data, 1)
            num_total += labels.size(0)
            num_correct += torch.sum(prediction == labels.data).item()

    valid_acc = 100 * num_correct / num_total
    if valid_acc > best_acc and epoch > 0:
        best_acc = valid_acc
        # save the best model
        model_name = "EfficientNet_savedModel.pth"
        torch.save(model_ft, model_name)
        print("The beat accuracy on the validation set is improved to " + str(best_acc) + "! Model saved to " + model_name)
    
    record_valid.append(valid_acc)
    loss_record_valid.append(valid_loss)
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc))
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc), file=mylog)
    print("************************************\n")
    print("************************************\n", file=mylog)
    mylog.close()
    
print("Training finished!")
# Out:
# Loaded pretrained weights for efficientnet-b4
# Start Training
# ========== epoch: [1/30] ==========
# LR is set to 0.01
# Epoch [1/30], Step [100/288], Training Loss: 4.1786 | Training accuracy: 22.031%
# Epoch [1/30], Step [200/288], Training Loss: 3.1371 | Training accuracy: 37.828%
# Epoch 1, Training Loss: 2.622 | Training accuracy: 45.033%
# --- cost time: 185.1922s ---
# *************** valid ***************
# Validation Loss: 0.608 | Validation accuracy: 85.127%
# ************************************
#
# ========== epoch: [2/30] ==========
# LR is set to 0.01
# Epoch [2/30], Step [100/288], Training Loss: 1.2252 | Training accuracy: 64.969%
# Epoch [2/30], Step [200/288], Training Loss: 1.2370 | Training accuracy: 64.781%
# Epoch 2, Training Loss: 1.250 | Training accuracy: 64.761%
# --- cost time: 180.0364s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 78.9628180039139! Model saved to EfficientNet_savedModel.pth
# Validation Loss: 0.748 | Validation accuracy: 78.963%
# ************************************
#
# ========== epoch: [3/30] ==========
# LR is set to 0.01
# Epoch [3/30], Step [100/288], Training Loss: 1.0483 | Training accuracy: 70.938%
# Epoch [3/30], Step [200/288], Training Loss: 1.0285 | Training accuracy: 70.734%
# Epoch 3, Training Loss: 1.040 | Training accuracy: 70.217%
# --- cost time: 181.9742s ---
# *************** valid ***************
# Validation Loss: 0.678 | Validation accuracy: 77.789%
# ************************************
#
# ========== epoch: [4/30] ==========
# LR is set to 0.01
# Epoch [4/30], Step [100/288], Training Loss: 0.9433 | Training accuracy: 73.469%
# Epoch [4/30], Step [200/288], Training Loss: 0.9221 | Training accuracy: 73.891%
# Epoch 4, Training Loss: 0.917 | Training accuracy: 73.978%
# --- cost time: 179.3853s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 79.45205479452055! Model saved to EfficientNet_savedModel.pth
# Validation Loss: 0.649 | Validation accuracy: 79.452%
# ************************************
#
# ========== epoch: [5/30] ==========
# LR is set to 0.01
# Epoch [5/30], Step [100/288], Training Loss: 0.8134 | Training accuracy: 76.750%
# Epoch [5/30], Step [200/288], Training Loss: 0.8426 | Training accuracy: 75.812%
# Epoch 5, Training Loss: 0.839 | Training accuracy: 75.815%
# --- cost time: 187.8824s ---
# *************** valid ***************
# Validation Loss: 0.778 | Validation accuracy: 78.082%
# ************************************
#
# ========== epoch: [6/30] ==========
# LR is set to 0.01
# Epoch [6/30], Step [100/288], Training Loss: 0.7668 | Training accuracy: 78.875%
# Epoch [6/30], Step [200/288], Training Loss: 0.7692 | Training accuracy: 78.516%
# Epoch 6, Training Loss: 0.770 | Training accuracy: 78.261%
# --- cost time: 184.8205s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 79.6477495107632! Model saved to EfficientNet_savedModel.pth
# Validation Loss: 0.690 | Validation accuracy: 79.648%
# ************************************
#
# ========== epoch: [7/30] ==========
# LR is set to 0.01
# Epoch [7/30], Step [100/288], Training Loss: 0.6637 | Training accuracy: 80.938%
# Epoch [7/30], Step [200/288], Training Loss: 0.7069 | Training accuracy: 79.969%
# Epoch 7, Training Loss: 0.717 | Training accuracy: 79.696%
# --- cost time: 184.8083s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 80.91976516634051! Model saved to EfficientNet_savedModel.pth
# Validation Loss: 0.685 | Validation accuracy: 80.920%
# ************************************
#
# ========== epoch: [8/30] ==========
# LR is set to 0.01
# Epoch [8/30], Step [100/288], Training Loss: 0.6284 | Training accuracy: 81.906%
# Epoch [8/30], Step [200/288], Training Loss: 0.6485 | Training accuracy: 81.203%
# Epoch 8, Training Loss: 0.665 | Training accuracy: 80.793%
# --- cost time: 179.1623s ---
# *************** valid ***************
# Validation Loss: 0.668 | Validation accuracy: 79.648%
# ************************************
#
# ========== epoch: [9/30] ==========
# LR is set to 0.01
# Epoch [9/30], Step [100/288], Training Loss: 0.6533 | Training accuracy: 81.844%
# Epoch [9/30], Step [200/288], Training Loss: 0.6485 | Training accuracy: 81.734%
# Epoch 9, Training Loss: 0.661 | Training accuracy: 81.478%
# --- cost time: 186.2287s ---
# *************** valid ***************
# Validation Loss: 0.764 | Validation accuracy: 78.082%
# ************************************
#
# ========== epoch: [10/30] ==========
# LR is set to 0.01
# Epoch [10/30], Step [100/288], Training Loss: 0.6459 | Training accuracy: 81.438%
# Epoch [10/30], Step [200/288], Training Loss: 0.6429 | Training accuracy: 81.562%
# Epoch 10, Training Loss: 0.648 | Training accuracy: 81.337%
# --- cost time: 189.6722s ---
# *************** valid ***************
# Validation Loss: 0.695 | Validation accuracy: 79.061%
# ************************************
#
# ========== epoch: [11/30] ==========
# LR is set to 0.008
# Epoch [11/30], Step [100/288], Training Loss: 0.5300 | Training accuracy: 85.500%
# Epoch [11/30], Step [200/288], Training Loss: 0.5463 | Training accuracy: 84.891%
# Epoch 11, Training Loss: 0.560 | Training accuracy: 84.500%
# --- cost time: 192.9712s ---
# *************** valid ***************
# Validation Loss: 0.665 | Validation accuracy: 80.724%
# ************************************
#
# ========== epoch: [12/30] ==========
# LR is set to 0.008
# Epoch [12/30], Step [100/288], Training Loss: 0.4692 | Training accuracy: 87.156%
# Epoch [12/30], Step [200/288], Training Loss: 0.5083 | Training accuracy: 85.609%
# Epoch 12, Training Loss: 0.522 | Training accuracy: 85.022%
# --- cost time: 188.4915s ---
# *************** valid ***************
# Validation Loss: 0.705 | Validation accuracy: 80.431%
# ************************************
#
# ========== epoch: [13/30] ==========
# LR is set to 0.008
# Epoch [13/30], Step [100/288], Training Loss: 0.4716 | Training accuracy: 86.969%
# Epoch [13/30], Step [200/288], Training Loss: 0.4787 | Training accuracy: 86.594%
# Epoch 13, Training Loss: 0.488 | Training accuracy: 86.359%
# --- cost time: 190.0719s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 81.11545988258317! Model saved to EfficientNet_savedModel.pth
# Validation Loss: 0.730 | Validation accuracy: 81.115%
# ************************************
#
# ========== epoch: [14/30] ==========
# LR is set to 0.008
# Epoch [14/30], Step [100/288], Training Loss: 0.4981 | Training accuracy: 85.969%
# Epoch [14/30], Step [200/288], Training Loss: 0.5018 | Training accuracy: 85.953%
# Epoch 14, Training Loss: 0.517 | Training accuracy: 85.652%
# --- cost time: 182.5790s ---
# *************** valid ***************
# Validation Loss: 0.755 | Validation accuracy: 80.431%
# ************************************
#
# ========== epoch: [15/30] ==========
# LR is set to 0.008
# Epoch [15/30], Step [100/288], Training Loss: 0.4449 | Training accuracy: 87.500%
# Epoch [15/30], Step [200/288], Training Loss: 0.4943 | Training accuracy: 86.266%
# Epoch 15, Training Loss: 0.490 | Training accuracy: 86.402%
# --- cost time: 181.3160s ---
# *************** valid ***************
# Validation Loss: 0.839 | Validation accuracy: 77.593%
# ************************************
#
# ========== epoch: [16/30] ==========
# LR is set to 0.008
# Epoch [16/30], Step [100/288], Training Loss: 0.4884 | Training accuracy: 86.562%
# Epoch [16/30], Step [200/288], Training Loss: 0.4755 | Training accuracy: 86.609%
# Epoch 16, Training Loss: 0.474 | Training accuracy: 86.870%
# --- cost time: 183.6386s ---
# *************** valid ***************
# Validation Loss: 0.808 | Validation accuracy: 79.354%
# ************************************
#
# ========== epoch: [17/30] ==========
# LR is set to 0.008
# Epoch [17/30], Step [100/288], Training Loss: 0.4373 | Training accuracy: 87.531%
# Epoch [17/30], Step [200/288], Training Loss: 0.4805 | Training accuracy: 86.469%
# Epoch 17, Training Loss: 0.492 | Training accuracy: 86.228%
# --- cost time: 183.5416s ---
# *************** valid ***************
# Validation Loss: 0.799 | Validation accuracy: 78.571%
# ************************************
#
# ========== epoch: [18/30] ==========
# LR is set to 0.008
# Epoch [18/30], Step [100/288], Training Loss: 0.5103 | Training accuracy: 86.469%
# Epoch [18/30], Step [200/288], Training Loss: 0.5105 | Training accuracy: 86.375%
# Epoch 18, Training Loss: 0.510 | Training accuracy: 86.098%
# --- cost time: 183.0123s ---
# *************** valid ***************
# Validation Loss: 0.790 | Validation accuracy: 80.333%
# ************************************
#
# ========== epoch: [19/30] ==========
# LR is set to 0.008
# Epoch [19/30], Step [100/288], Training Loss: 0.4606 | Training accuracy: 86.656%
# Epoch [19/30], Step [200/288], Training Loss: 0.4622 | Training accuracy: 87.078%
# Epoch 19, Training Loss: 0.477 | Training accuracy: 86.750%
# --- cost time: 183.2145s ---
# *************** valid ***************
# Validation Loss: 0.824 | Validation accuracy: 78.571%
# ************************************
#
# ========== epoch: [20/30] ==========
# LR is set to 0.008
# Epoch [20/30], Step [100/288], Training Loss: 0.4440 | Training accuracy: 88.062%
# Epoch [20/30], Step [200/288], Training Loss: 0.4786 | Training accuracy: 86.781%
# Epoch 20, Training Loss: 0.486 | Training accuracy: 86.370%
# --- cost time: 184.9111s ---
# *************** valid ***************
# Validation Loss: 0.918 | Validation accuracy: 77.495%
# ************************************
#
# ========== epoch: [21/30] ==========
# LR is set to 0.006400000000000001
# Epoch [21/30], Step [100/288], Training Loss: 0.4242 | Training accuracy: 88.500%
# Epoch [21/30], Step [200/288], Training Loss: 0.4277 | Training accuracy: 88.266%
# Epoch 21, Training Loss: 0.430 | Training accuracy: 88.239%
# --- cost time: 180.2187s ---
# *************** valid ***************
# Validation Loss: 0.782 | Validation accuracy: 80.235%
# ************************************
#
# ========== epoch: [22/30] ==========
# LR is set to 0.006400000000000001
# Epoch [22/30], Step [100/288], Training Loss: 0.3398 | Training accuracy: 91.062%
# Epoch [22/30], Step [200/288], Training Loss: 0.3864 | Training accuracy: 89.531%
# Epoch 22, Training Loss: 0.400 | Training accuracy: 89.217%
# --- cost time: 183.1988s ---
# *************** valid ***************
# Validation Loss: 0.852 | Validation accuracy: 77.886%
# ************************************
#
# ========== epoch: [23/30] ==========
# LR is set to 0.006400000000000001
# Epoch [23/30], Step [100/288], Training Loss: 0.4464 | Training accuracy: 87.562%
# Epoch [23/30], Step [200/288], Training Loss: 0.4113 | Training accuracy: 88.641%
# Epoch 23, Training Loss: 0.416 | Training accuracy: 88.489%
# --- cost time: 180.3493s ---
# *************** valid ***************
# Validation Loss: 0.823 | Validation accuracy: 79.256%
# ************************************
#
# ========== epoch: [24/30] ==========
# LR is set to 0.006400000000000001
# Epoch [24/30], Step [100/288], Training Loss: 0.4223 | Training accuracy: 88.562%
# Epoch [24/30], Step [200/288], Training Loss: 0.4119 | Training accuracy: 88.562%
# Epoch 24, Training Loss: 0.415 | Training accuracy: 88.446%
# --- cost time: 181.2495s ---
# *************** valid ***************
# Validation Loss: 0.798 | Validation accuracy: 79.452%
# ************************************
#
# ========== epoch: [25/30] ==========
# LR is set to 0.006400000000000001
# Epoch [25/30], Step [100/288], Training Loss: 0.3832 | Training accuracy: 89.875%
# Epoch [25/30], Step [200/288], Training Loss: 0.4036 | Training accuracy: 88.922%
# Epoch 25, Training Loss: 0.400 | Training accuracy: 88.946%
# --- cost time: 184.0430s ---
# *************** valid ***************
# Validation Loss: 0.822 | Validation accuracy: 79.354%
# ************************************
#
# ========== epoch: [26/30] ==========
# LR is set to 0.006400000000000001
# Epoch [26/30], Step [100/288], Training Loss: 0.4291 | Training accuracy: 87.938%
# Epoch [26/30], Step [200/288], Training Loss: 0.4099 | Training accuracy: 88.234%
# Epoch 26, Training Loss: 0.415 | Training accuracy: 88.304%
# --- cost time: 188.8763s ---
# *************** valid ***************
# Validation Loss: 0.895 | Validation accuracy: 76.223%
# ************************************
#
# ========== epoch: [27/30] ==========
# LR is set to 0.006400000000000001
# Epoch [27/30], Step [100/288], Training Loss: 0.4020 | Training accuracy: 88.875%
# Epoch [27/30], Step [200/288], Training Loss: 0.4235 | Training accuracy: 88.500%
# Epoch 27, Training Loss: 0.429 | Training accuracy: 88.272%
# --- cost time: 189.3838s ---
# *************** valid ***************
# Validation Loss: 0.882 | Validation accuracy: 78.180%
# ************************************
#
# ========== epoch: [28/30] ==========
# LR is set to 0.006400000000000001
# Epoch [28/30], Step [100/288], Training Loss: 0.4034 | Training accuracy: 89.344%
# Epoch [28/30], Step [200/288], Training Loss: 0.4180 | Training accuracy: 88.781%
# Epoch 28, Training Loss: 0.416 | Training accuracy: 88.457%
# --- cost time: 191.4427s ---
# *************** valid ***************
# Validation Loss: 0.924 | Validation accuracy: 76.517%
# ************************************
#
# ========== epoch: [29/30] ==========
# LR is set to 0.006400000000000001
# Epoch [29/30], Step [100/288], Training Loss: 0.3929 | Training accuracy: 89.625%
# Epoch [29/30], Step [200/288], Training Loss: 0.3997 | Training accuracy: 89.062%
# Epoch 29, Training Loss: 0.411 | Training accuracy: 88.859%
# --- cost time: 188.6636s ---
# *************** valid ***************
# Validation Loss: 0.892 | Validation accuracy: 78.082%
# ************************************
#
# ========== epoch: [30/30] ==========
# LR is set to 0.006400000000000001
# Epoch [30/30], Step [100/288], Training Loss: 0.4470 | Training accuracy: 87.281%
# Epoch [30/30], Step [200/288], Training Loss: 0.4300 | Training accuracy: 87.953%
# Epoch 30, Training Loss: 0.437 | Training accuracy: 87.674%
# --- cost time: 181.5280s ---
# *************** valid ***************
# Validation Loss: 0.979 | Validation accuracy: 76.027%
# ************************************
#
# Training finished!

# %%
# Visualize the change of the accuracy
train_acc_result = []
for record in record_train:
    train_acc_result.append(record.cuda().data.cpu().numpy())

plt.style.use("ggplot")
plt.plot(range(1, len(train_acc_result) + 1), train_acc_result, label="train acc")
if record_valid is not None:
    plt.plot(range(1, len(record_valid) + 1), record_valid, label="valid acc")

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("learning accuracy curve")
plt.xticks(range(0, len(train_acc_result) + 1, 5))
plt.yticks(range(0, 101, 5))
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.show()

# %%
# Visualize the change of the loss
train_loss_result = []
for record in loss_record_train:
    train_loss_result.append(record)

plt.style.use("ggplot")
plt.plot(range(1, len(train_loss_result) + 1), train_loss_result, label="train loss")

valid_loss_result = []
for record in loss_record_valid:
    valid_loss_result.append(record.cuda().data.cpu().numpy())
plt.plot(range(1, len(valid_loss_result) + 1), valid_loss_result, label="valid loss")

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("learning loss curve")
plt.xticks(range(0, len(train_loss_result) + 1, 5))
plt.yticks(range(0, 5, 1))
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
