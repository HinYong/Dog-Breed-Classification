# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import matplotlib.pyplot as plt
import os
import time
from torch.autograd import Variable

# %%
train_dir = './data/train_valid/train'
valid_dir = './data/train_valid/valid'

# %%
# Preprocess the data
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.08, 1.0), ratio=(3.0/4.0, 4.0/3.0)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

valid_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# train_transforms = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.485, 0.456, 0.406], 
#                                                             [0.229, 0.224, 0.225])])

# valid_transforms = transforms.Compose([transforms.Resize(256),
#                                        transforms.CenterCrop(224),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.485, 0.456, 0.406], 
#                                                             [0.229, 0.224, 0.225])])

# %%
# Load the datasets with ImageFolder and preprocess
train_data = torchvision.datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = torchvision.datasets.ImageFolder(valid_dir, transform=valid_transforms)

# Use the datasets and the transforms to define the dataloaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=32, shuffle=True)

# %%
# Adjust the learning rate
def lr_scheduler(optimizer, epoch, init_lr=0.01, lr_decay_epoch=10):
    lr = init_lr * (0.8 ** (epoch // lr_decay_epoch))
    print('LR is set to {}'.format(lr))
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
    return optimizer

# %%
use_gpu = torch.cuda.is_available()
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
num_epochs = 30

# Load the model
model_ft = models.densenet169(pretrained=True)
num_ftrs = model_ft.classifier.in_features
# Change the classify layer
model_ft.classifier = nn.Linear(num_ftrs, 120) 
# # Freeze the parameter
# for param in model_ft.features.parameters():
#     param.requires_grad = False
# Use CrossEntropyLoss as the loss function
criterion = nn.CrossEntropyLoss()
# Use SGD as the optimizer
optimizer = optim.SGD((model_ft.parameters()), lr=0.01, momentum=0.9, weight_decay=1e-4)
if use_gpu:
    model_ft = model_ft.cuda()
    criterion = criterion.cuda()

print('Start Training')
total_step = len(train_loader)
best_acc = 0
model_ft.train(True)
record_train = list()
record_valid = list()
loss_record_train = list()
loss_record_valid = list()

for epoch in range(num_epochs):
    # Save the training process
    mylog = open('DenseNet169_training_progress.log', mode='a', encoding='utf-8')
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs), file=mylog)
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs))
    num_correct = 0
    num_total = 0
    
    start = time.time()
    # Adjust the learning rate
    optimizer = lr_scheduler(optimizer, epoch)
    # Initialize training loss
    train_loss = 0.0
    valid_loss = 0.0
    # Start training the model
    for i, (inputs, labels) in enumerate(train_loader):
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        # Clear the gradient
        optimizer.zero_grad()
        # Feed forward
        outputs = model_ft(inputs)
        loss = criterion(outputs, labels)
        # Back propagation
        loss.backward()
        optimizer.step()
        # Predict
        _, prediction = torch.max(outputs.data, 1)
        num_total += labels.size(0)
        num_correct += torch.sum(prediction == labels.data)
        train_acc = 100.0 * num_correct / num_total
        train_loss = train_loss + ((1 / (i + 1)) * (loss.data - train_loss)) 

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs, i + 1, total_step, train_loss, train_acc))
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs, i + 1, total_step, train_loss, train_acc), file=mylog)

    record_train.append(train_acc)
    loss_record_train.append(loss.item())
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc))
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc), file=mylog)
    print("--- cost time: {:.4f}s ---".format(time.time() - start))
    print("--- cost time: {:.4f}s ---".format(time.time() - start), file=mylog)

    # test on the validation set
    print("*************** valid ***************")
    print("*************** valid ***************", file=mylog)
    with torch.no_grad():
        num_correct = 0
        num_total = 0
        for i, (inputs, labels) in enumerate(valid_loader):
            model_ft.eval()
            inputs = torch.autograd.Variable(inputs.cuda())
            labels = torch.autograd.Variable(labels.cuda())

            outputs = model_ft(inputs)
            loss = criterion(outputs, labels)
            valid_loss += ((1 / (i + 1)) * (loss.data - valid_loss))
            _, prediction = torch.max(outputs.data, 1)
            num_total += labels.size(0)
            num_correct += torch.sum(prediction == labels.data).item()

    valid_acc = 100 * num_correct / num_total
    if valid_acc > best_acc:
        best_acc = valid_acc
        # save the best model
        model_name = "DenseNet169_savedModel.pth"
        torch.save(model_ft, model_name)
        print("The beat accuracy on the validation set is improved to " + str(best_acc) + "! Model saved to " + model_name)
    
    record_valid.append(valid_acc)
    loss_record_valid.append(valid_loss)
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc))
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc), file=mylog)
    print("************************************\n")
    print("************************************\n", file=mylog)
    mylog.close()
    
print("Training finished!")
# Out:
# Start Training
# ========== epoch: [1/30] ==========
# LR is set to 0.01
# Epoch [1/30], Step [100/288], Training Loss: 3.2139 | Training accuracy: 26.406%
# Epoch [1/30], Step [200/288], Training Loss: 2.8674 | Training accuracy: 30.797%
# Epoch 1, Training Loss: 2.714 | Training accuracy: 33.489%
# --- cost time: 143.6935s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 50.391389432485326! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.761 | Validation accuracy: 50.391%
# ************************************
#
# ========== epoch: [2/30] ==========
# LR is set to 0.01
# Epoch [2/30], Step [100/288], Training Loss: 4.7679 | Training accuracy:  1.594%
# Epoch [2/30], Step [200/288], Training Loss: 4.7736 | Training accuracy:  1.359%
# Epoch 2, Training Loss: 4.766 | Training accuracy:  1.359%
# --- cost time: 140.6689s ---
# *************** valid ***************
# Validation Loss: 4.735 | Validation accuracy:  1.468%
# ************************************
#
# ========== epoch: [3/30] ==========
# LR is set to 0.01
# Epoch [3/30], Step [100/288], Training Loss: 4.7287 | Training accuracy:  1.531%
# Epoch [3/30], Step [200/288], Training Loss: 4.7105 | Training accuracy:  1.750%
# Epoch 3, Training Loss: 4.694 | Training accuracy:  2.141%
# --- cost time: 140.6420s ---
# *************** valid ***************
# Validation Loss: 4.697 | Validation accuracy:  1.761%
# ************************************
#
# ========== epoch: [4/30] ==========
# LR is set to 0.01
# Epoch [4/30], Step [100/288], Training Loss: 4.6396 | Training accuracy:  2.406%
# Epoch [4/30], Step [200/288], Training Loss: 4.6552 | Training accuracy:  2.328%
# Epoch 4, Training Loss: 4.646 | Training accuracy:  2.467%
# --- cost time: 141.9193s ---
# *************** valid ***************
# Validation Loss: 4.304 | Validation accuracy:  5.577%
# ************************************
#
# ========== epoch: [5/30] ==========
# LR is set to 0.01
# Epoch [5/30], Step [100/288], Training Loss: 4.2631 | Training accuracy:  5.781%
# Epoch [5/30], Step [200/288], Training Loss: 4.1187 | Training accuracy:  8.156%
# Epoch 5, Training Loss: 3.951 | Training accuracy: 10.554%
# --- cost time: 141.3472s ---
# *************** valid ***************
# Validation Loss: 2.917 | Validation accuracy: 26.517%
# ************************************
#
# ========== epoch: [6/30] ==========
# LR is set to 0.01
# Epoch [6/30], Step [100/288], Training Loss: 3.3084 | Training accuracy: 20.812%
# Epoch [6/30], Step [200/288], Training Loss: 3.2324 | Training accuracy: 21.672%
# Epoch 6, Training Loss: 3.210 | Training accuracy: 22.033%
# --- cost time: 140.5511s ---
# *************** valid ***************
# Validation Loss: 2.481 | Validation accuracy: 33.855%
# ************************************
#
# ========== epoch: [7/30] ==========
# LR is set to 0.01
# Epoch [7/30], Step [100/288], Training Loss: 3.0640 | Training accuracy: 24.062%
# Epoch [7/30], Step [200/288], Training Loss: 3.0278 | Training accuracy: 25.594%
# Epoch 7, Training Loss: 2.989 | Training accuracy: 26.348%
# --- cost time: 140.9780s ---
# *************** valid ***************
# Validation Loss: 2.372 | Validation accuracy: 36.204%
# ************************************
#
# ========== epoch: [8/30] ==========
# LR is set to 0.01
# Epoch [8/30], Step [100/288], Training Loss: 2.7991 | Training accuracy: 28.781%
# Epoch [8/30], Step [200/288], Training Loss: 2.8006 | Training accuracy: 29.281%
# Epoch 8, Training Loss: 2.781 | Training accuracy: 29.587%
# --- cost time: 141.1551s ---
# *************** valid ***************
# Validation Loss: 2.401 | Validation accuracy: 36.693%
# ************************************
#
# ========== epoch: [9/30] ==========
# LR is set to 0.01
# Epoch [9/30], Step [100/288], Training Loss: 2.6276 | Training accuracy: 32.469%
# Epoch [9/30], Step [200/288], Training Loss: 2.6269 | Training accuracy: 33.109%
# Epoch 9, Training Loss: 2.642 | Training accuracy: 32.641%
# --- cost time: 139.5274s ---
# *************** valid ***************
# Validation Loss: 2.679 | Validation accuracy: 30.039%
# ************************************
#
# ========== epoch: [10/30] ==========
# LR is set to 0.01
# Epoch [10/30], Step [100/288], Training Loss: 2.5753 | Training accuracy: 33.688%
# Epoch [10/30], Step [200/288], Training Loss: 2.5509 | Training accuracy: 34.562%
# Epoch 10, Training Loss: 2.538 | Training accuracy: 34.891%
# --- cost time: 140.6221s ---
# *************** valid ***************
# Validation Loss: 2.160 | Validation accuracy: 42.661%
# ************************************
#
# ========== epoch: [11/30] ==========
# LR is set to 0.008
# Epoch [11/30], Step [100/288], Training Loss: 2.2293 | Training accuracy: 42.031%
# Epoch [11/30], Step [200/288], Training Loss: 2.2096 | Training accuracy: 42.141%
# Epoch 11, Training Loss: 2.198 | Training accuracy: 42.348%
# --- cost time: 141.0565s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 50.97847358121331! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.717 | Validation accuracy: 50.978%
# ************************************
#
# ========== epoch: [12/30] ==========
# LR is set to 0.008
# Epoch [12/30], Step [100/288], Training Loss: 2.0038 | Training accuracy: 46.906%
# Epoch [12/30], Step [200/288], Training Loss: 2.0265 | Training accuracy: 45.828%
# Epoch 12, Training Loss: 2.076 | Training accuracy: 44.804%
# --- cost time: 141.5956s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 51.56555772994129! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.811 | Validation accuracy: 51.566%
# ************************************
#
# ========== epoch: [13/30] ==========
# LR is set to 0.008
# Epoch [13/30], Step [100/288], Training Loss: 2.0436 | Training accuracy: 45.469%
# Epoch [13/30], Step [200/288], Training Loss: 2.0105 | Training accuracy: 46.375%
# Epoch 13, Training Loss: 2.021 | Training accuracy: 46.293%
# --- cost time: 139.9144s ---
# *************** valid ***************
# Validation Loss: 1.886 | Validation accuracy: 48.043%
# ************************************
#
# ========== epoch: [14/30] ==========
# LR is set to 0.008
# Epoch [14/30], Step [100/288], Training Loss: 1.8683 | Training accuracy: 49.438%
# Epoch [14/30], Step [200/288], Training Loss: 1.9233 | Training accuracy: 48.578%
# Epoch 14, Training Loss: 1.933 | Training accuracy: 48.315%
# --- cost time: 139.7048s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 57.240704500978474! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.515 | Validation accuracy: 57.241%
# ************************************
#
# ========== epoch: [15/30] ==========
# LR is set to 0.008
# Epoch [15/30], Step [100/288], Training Loss: 1.9033 | Training accuracy: 49.219%
# Epoch [15/30], Step [200/288], Training Loss: 1.9185 | Training accuracy: 48.484%
# Epoch 15, Training Loss: 1.915 | Training accuracy: 48.924%
# --- cost time: 139.6499s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 58.21917808219178! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.450 | Validation accuracy: 58.219%
# ************************************
#
# ========== epoch: [16/30] ==========
# LR is set to 0.008
# Epoch [16/30], Step [100/288], Training Loss: 1.7946 | Training accuracy: 51.656%
# Epoch [16/30], Step [200/288], Training Loss: 1.8140 | Training accuracy: 51.594%
# Epoch 16, Training Loss: 1.842 | Training accuracy: 50.924%
# --- cost time: 139.5732s ---
# *************** valid ***************
# Validation Loss: 1.632 | Validation accuracy: 55.088%
# ************************************
#
# ========== epoch: [17/30] ==========
# LR is set to 0.008
# Epoch [17/30], Step [100/288], Training Loss: 1.8223 | Training accuracy: 51.469%
# Epoch [17/30], Step [200/288], Training Loss: 1.8298 | Training accuracy: 51.094%
# Epoch 17, Training Loss: 1.854 | Training accuracy: 50.304%
# --- cost time: 139.3929s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 58.806262230919764! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.504 | Validation accuracy: 58.806%
# ************************************
#
# ========== epoch: [18/30] ==========
# LR is set to 0.008
# Epoch [18/30], Step [100/288], Training Loss: 1.7646 | Training accuracy: 54.031%
# Epoch [18/30], Step [200/288], Training Loss: 1.7836 | Training accuracy: 53.422%
# Epoch 18, Training Loss: 1.782 | Training accuracy: 52.696%
# --- cost time: 140.9370s ---
# *************** valid ***************
# Validation Loss: 1.536 | Validation accuracy: 57.045%
# ************************************
#
# ========== epoch: [19/30] ==========
# LR is set to 0.008
# Epoch [19/30], Step [100/288], Training Loss: 1.7226 | Training accuracy: 54.500%
# Epoch [19/30], Step [200/288], Training Loss: 1.7297 | Training accuracy: 53.859%
# Epoch 19, Training Loss: 1.714 | Training accuracy: 53.902%
# --- cost time: 140.1965s ---
# *************** valid ***************
# Validation Loss: 1.568 | Validation accuracy: 58.023%
# ************************************
#
# ========== epoch: [20/30] ==========
# LR is set to 0.008
# Epoch [20/30], Step [100/288], Training Loss: 1.7083 | Training accuracy: 53.438%
# Epoch [20/30], Step [200/288], Training Loss: 1.7095 | Training accuracy: 53.719%
# Epoch 20, Training Loss: 1.708 | Training accuracy: 53.978%
# --- cost time: 140.7270s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 60.95890410958904! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.479 | Validation accuracy: 60.959%
# ************************************
#
# ========== epoch: [21/30] ==========
# LR is set to 0.006400000000000001
# Epoch [21/30], Step [100/288], Training Loss: 1.6069 | Training accuracy: 55.656%
# Epoch [21/30], Step [200/288], Training Loss: 1.5703 | Training accuracy: 57.125%
# Epoch 21, Training Loss: 1.531 | Training accuracy: 57.957%
# --- cost time: 141.2608s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 62.23091976516634! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.349 | Validation accuracy: 62.231%
# ************************************
#
# ========== epoch: [22/30] ==========
# LR is set to 0.006400000000000001
# Epoch [22/30], Step [100/288], Training Loss: 1.4190 | Training accuracy: 60.781%
# Epoch [22/30], Step [200/288], Training Loss: 1.4527 | Training accuracy: 59.938%
# Epoch 22, Training Loss: 1.461 | Training accuracy: 59.761%
# --- cost time: 141.1160s ---
# *************** valid ***************
# Validation Loss: 1.364 | Validation accuracy: 61.546%
# ************************************
#
# ========== epoch: [23/30] ==========
# LR is set to 0.006400000000000001
# Epoch [23/30], Step [100/288], Training Loss: 1.3806 | Training accuracy: 62.438%
# Epoch [23/30], Step [200/288], Training Loss: 1.4034 | Training accuracy: 62.250%
# Epoch 23, Training Loss: 1.418 | Training accuracy: 61.891%
# --- cost time: 141.6770s ---
# *************** valid ***************
# Validation Loss: 1.407 | Validation accuracy: 61.742%
# ************************************
#
# ========== epoch: [24/30] ==========
# LR is set to 0.006400000000000001
# Epoch [24/30], Step [100/288], Training Loss: 1.4059 | Training accuracy: 61.062%
# Epoch [24/30], Step [200/288], Training Loss: 1.4204 | Training accuracy: 61.047%
# Epoch 24, Training Loss: 1.410 | Training accuracy: 61.207%
# --- cost time: 140.9833s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 63.60078277886497! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.338 | Validation accuracy: 63.601%
# ************************************
#
# ========== epoch: [25/30] ==========
# LR is set to 0.006400000000000001
# Epoch [25/30], Step [100/288], Training Loss: 1.3029 | Training accuracy: 63.750%
# Epoch [25/30], Step [200/288], Training Loss: 1.3786 | Training accuracy: 62.000%
# Epoch 25, Training Loss: 1.389 | Training accuracy: 61.457%
# --- cost time: 141.2145s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 64.6771037181996! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.301 | Validation accuracy: 64.677%
# ************************************
#
# ========== epoch: [26/30] ==========
# LR is set to 0.006400000000000001
# Epoch [26/30], Step [100/288], Training Loss: 1.3194 | Training accuracy: 64.500%
# Epoch [26/30], Step [200/288], Training Loss: 1.3416 | Training accuracy: 63.453%
# Epoch 26, Training Loss: 1.355 | Training accuracy: 62.957%
# --- cost time: 140.1654s ---
# *************** valid ***************
# Validation Loss: 1.351 | Validation accuracy: 64.384%
# ************************************
#
# ========== epoch: [27/30] ==========
# LR is set to 0.006400000000000001
# Epoch [27/30], Step [100/288], Training Loss: 1.3005 | Training accuracy: 64.750%
# Epoch [27/30], Step [200/288], Training Loss: 1.3317 | Training accuracy: 63.547%
# Epoch 27, Training Loss: 1.342 | Training accuracy: 63.152%
# --- cost time: 140.8433s ---
# *************** valid ***************
# Validation Loss: 1.347 | Validation accuracy: 64.286%
# ************************************
#
# ========== epoch: [28/30] ==========
# LR is set to 0.006400000000000001
# Epoch [28/30], Step [100/288], Training Loss: 1.2620 | Training accuracy: 65.031%
# Epoch [28/30], Step [200/288], Training Loss: 1.2591 | Training accuracy: 65.219%
# Epoch 28, Training Loss: 1.270 | Training accuracy: 64.728%
# --- cost time: 140.2697s ---
# *************** valid ***************
# Validation Loss: 1.318 | Validation accuracy: 62.916%
# ************************************
#
# ========== epoch: [29/30] ==========
# LR is set to 0.006400000000000001
# Epoch [29/30], Step [100/288], Training Loss: 1.2494 | Training accuracy: 65.625%
# Epoch [29/30], Step [200/288], Training Loss: 1.2703 | Training accuracy: 65.016%
# Epoch 29, Training Loss: 1.279 | Training accuracy: 64.772%
# --- cost time: 140.9668s ---
# *************** valid ***************
# Validation Loss: 1.370 | Validation accuracy: 64.384%
# ************************************
#
# ========== epoch: [30/30] ==========
# LR is set to 0.006400000000000001
# Epoch [30/30], Step [100/288], Training Loss: 1.2346 | Training accuracy: 66.062%
# Epoch [30/30], Step [200/288], Training Loss: 1.2557 | Training accuracy: 65.312%
# Epoch 30, Training Loss: 1.273 | Training accuracy: 64.891%
# --- cost time: 141.1919s ---
# *************** valid ***************
# Validation Loss: 1.425 | Validation accuracy: 64.481%
# ************************************
#
# Training finished!

# %%
# add 20 more iteration
for epoch in range(num_epochs, num_epochs+20):
    # Save the training process
    mylog = open('DenseNet169_training_progress.log', mode='a', encoding='utf-8')
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs+20), file=mylog)
    print("========== epoch: [{}/{}] ==========".format(epoch + 1, num_epochs+20))
    num_correct = 0
    num_total = 0
    
    start = time.time()
    # Adjust the learning rate
    optimizer = lr_scheduler(optimizer, epoch)
    # Initialize training loss
    train_loss = 0.0
    valid_loss = 0.0
    # Start training the model
    for i, (inputs, labels) in enumerate(train_loader):
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        # Clear the gradient
        optimizer.zero_grad()
        # Feed forward
        outputs = model_ft(inputs)
        loss = criterion(outputs, labels)
        # Back propagation
        loss.backward()
        optimizer.step()
        # Predict
        _, prediction = torch.max(outputs.data, 1)
        num_total += labels.size(0)
        num_correct += torch.sum(prediction == labels.data)
        train_acc = 100.0 * num_correct / num_total
        train_loss = train_loss + ((1 / (i + 1)) * (loss.data - train_loss)) 

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs+20, i + 1, total_step, train_loss, train_acc))
            print('Epoch [{}/{}], Step [{}/{}], Training Loss: {:.4f} | Training accuracy: {:6.3f}%'.
                  format(epoch + 1, num_epochs+20, i + 1, total_step, train_loss, train_acc), file=mylog)

    record_train.append(train_acc)
    loss_record_train.append(loss.item())
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc))
    print('Epoch {}, Training Loss: {:.3f} | Training accuracy: {:6.3f}%'.format(epoch + 1, train_loss, train_acc), file=mylog)
    print("--- cost time: {:.4f}s ---".format(time.time() - start))
    print("--- cost time: {:.4f}s ---".format(time.time() - start), file=mylog)

    # test on the validation set
    print("*************** valid ***************")
    print("*************** valid ***************", file=mylog)
    with torch.no_grad():
        num_correct = 0
        num_total = 0
        for i, (inputs, labels) in enumerate(valid_loader):
            model_ft.eval()
            inputs = torch.autograd.Variable(inputs.cuda())
            labels = torch.autograd.Variable(labels.cuda())

            outputs = model_ft(inputs)
            loss = criterion(outputs, labels)
            valid_loss += ((1 / (i + 1)) * (loss.data - valid_loss))
            _, prediction = torch.max(outputs.data, 1)
            num_total += labels.size(0)
            num_correct += torch.sum(prediction == labels.data).item()

    valid_acc = 100 * num_correct / num_total
    if valid_acc > best_acc:
        best_acc = valid_acc
        # save the best model
        model_name = "DenseNet169_savedModel.pth"
        torch.save(model_ft, model_name)
        print("The beat accuracy on the validation set is improved to " + str(best_acc) + "! Model saved to " + model_name)
    
    record_valid.append(valid_acc)
    loss_record_valid.append(valid_loss)
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc))
    print("Validation Loss: {:.3f} | Validation accuracy: {:6.3f}%".format(valid_loss, valid_acc), file=mylog)
    print("************************************\n")
    print("************************************\n", file=mylog)
    mylog.close()
# Out:
# ========== epoch: [31/50] ==========
# LR is set to 0.005120000000000001
# Epoch [31/50], Step [100/288], Training Loss: 1.1137 | Training accuracy: 69.062%
# Epoch [31/50], Step [200/288], Training Loss: 1.1373 | Training accuracy: 67.750%
# Epoch 31, Training Loss: 1.144 | Training accuracy: 67.924%
# --- cost time: 141.2050s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 65.36203522504893! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.243 | Validation accuracy: 65.362%
# ************************************
#
# ========== epoch: [32/50] ==========
# LR is set to 0.005120000000000001
# Epoch [32/50], Step [100/288], Training Loss: 1.0190 | Training accuracy: 71.531%
# Epoch [32/50], Step [200/288], Training Loss: 1.0398 | Training accuracy: 71.000%
# Epoch 32, Training Loss: 1.063 | Training accuracy: 70.620%
# --- cost time: 140.0108s ---
# *************** valid ***************
# Validation Loss: 1.253 | Validation accuracy: 65.362%
# ************************************
#
# ========== epoch: [33/50] ==========
# LR is set to 0.005120000000000001
# Epoch [33/50], Step [100/288], Training Loss: 1.0403 | Training accuracy: 71.156%
# Epoch [33/50], Step [200/288], Training Loss: 1.0379 | Training accuracy: 71.297%
# Epoch 33, Training Loss: 1.048 | Training accuracy: 71.348%
# --- cost time: 139.9264s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 66.34050880626224! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.368 | Validation accuracy: 66.341%
# ************************************
#
# ========== epoch: [34/50] ==========
# LR is set to 0.005120000000000001
# Epoch [34/50], Step [100/288], Training Loss: 1.0038 | Training accuracy: 71.562%
# Epoch [34/50], Step [200/288], Training Loss: 1.0169 | Training accuracy: 71.562%
# Epoch 34, Training Loss: 1.036 | Training accuracy: 71.076%
# --- cost time: 140.2963s ---
# *************** valid ***************
# Validation Loss: 1.297 | Validation accuracy: 65.558%
# ************************************
#
# ========== epoch: [35/50] ==========
# LR is set to 0.005120000000000001
# Epoch [35/50], Step [100/288], Training Loss: 1.0111 | Training accuracy: 72.281%
# Epoch [35/50], Step [200/288], Training Loss: 1.0065 | Training accuracy: 72.375%
# Epoch 35, Training Loss: 1.023 | Training accuracy: 71.837%
# --- cost time: 140.4448s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 67.02544031311155! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.316 | Validation accuracy: 67.025%
# ************************************
#
# ========== epoch: [36/50] ==========
# LR is set to 0.005120000000000001
# Epoch [36/50], Step [100/288], Training Loss: 0.9812 | Training accuracy: 73.188%
# Epoch [36/50], Step [200/288], Training Loss: 1.0026 | Training accuracy: 72.484%
# Epoch 36, Training Loss: 1.011 | Training accuracy: 72.174%
# --- cost time: 139.2206s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 67.41682974559687! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.287 | Validation accuracy: 67.417%
# ************************************
#
# ========== epoch: [37/50] ==========
# LR is set to 0.005120000000000001
# Epoch [37/50], Step [100/288], Training Loss: 0.9774 | Training accuracy: 72.969%
# Epoch [37/50], Step [200/288], Training Loss: 0.9950 | Training accuracy: 72.156%
# Epoch 37, Training Loss: 1.001 | Training accuracy: 71.989%
# --- cost time: 140.1431s ---
# *************** valid ***************
# Validation Loss: 1.274 | Validation accuracy: 66.928%
# ************************************
#
# ========== epoch: [38/50] ==========
# LR is set to 0.005120000000000001
# Epoch [38/50], Step [100/288], Training Loss: 0.9574 | Training accuracy: 73.031%
# Epoch [38/50], Step [200/288], Training Loss: 0.9871 | Training accuracy: 72.109%
# Epoch 38, Training Loss: 0.991 | Training accuracy: 72.141%
# --- cost time: 141.5127s ---
# *************** valid ***************
# Validation Loss: 1.301 | Validation accuracy: 66.536%
# ************************************
#
# ========== epoch: [39/50] ==========
# LR is set to 0.005120000000000001
# Epoch [39/50], Step [100/288], Training Loss: 0.9407 | Training accuracy: 73.594%
# Epoch [39/50], Step [200/288], Training Loss: 0.9426 | Training accuracy: 73.781%
# Epoch 39, Training Loss: 0.958 | Training accuracy: 73.217%
# --- cost time: 140.8576s ---
# *************** valid ***************
# Validation Loss: 1.384 | Validation accuracy: 66.243%
# ************************************
#
# ========== epoch: [40/50] ==========
# LR is set to 0.005120000000000001
# Epoch [40/50], Step [100/288], Training Loss: 0.9635 | Training accuracy: 73.188%
# Epoch [40/50], Step [200/288], Training Loss: 0.9612 | Training accuracy: 73.828%
# Epoch 40, Training Loss: 0.953 | Training accuracy: 73.848%
# --- cost time: 140.6112s ---
# *************** valid ***************
# Validation Loss: 1.386 | Validation accuracy: 65.558%
# ************************************
#
# ========== epoch: [41/50] ==========
# LR is set to 0.004096000000000001
# Epoch [41/50], Step [100/288], Training Loss: 0.8674 | Training accuracy: 75.938%
# Epoch [41/50], Step [200/288], Training Loss: 0.8481 | Training accuracy: 76.938%
# Epoch 41, Training Loss: 0.861 | Training accuracy: 76.261%
# --- cost time: 140.3022s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 68.19960861056751! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.313 | Validation accuracy: 68.200%
# ************************************
#
# ========== epoch: [42/50] ==========
# LR is set to 0.004096000000000001
# Epoch [42/50], Step [100/288], Training Loss: 0.8035 | Training accuracy: 78.594%
# Epoch [42/50], Step [200/288], Training Loss: 0.8084 | Training accuracy: 78.141%
# Epoch 42, Training Loss: 0.817 | Training accuracy: 77.696%
# --- cost time: 140.8070s ---
# *************** valid ***************
# Validation Loss: 1.456 | Validation accuracy: 66.634%
# ************************************
#
# ========== epoch: [43/50] ==========
# LR is set to 0.004096000000000001
# Epoch [43/50], Step [100/288], Training Loss: 0.7539 | Training accuracy: 79.719%
# Epoch [43/50], Step [200/288], Training Loss: 0.7891 | Training accuracy: 78.375%
# Epoch 43, Training Loss: 0.803 | Training accuracy: 77.783%
# --- cost time: 141.4330s ---
# *************** valid ***************
# Validation Loss: 1.312 | Validation accuracy: 67.515%
# ************************************
#
# ========== epoch: [44/50] ==========
# LR is set to 0.004096000000000001
# Epoch [44/50], Step [100/288], Training Loss: 0.8250 | Training accuracy: 77.781%
# Epoch [44/50], Step [200/288], Training Loss: 0.8098 | Training accuracy: 77.891%
# Epoch 44, Training Loss: 0.813 | Training accuracy: 77.630%
# --- cost time: 140.5449s ---
# *************** valid ***************
# The beat accuracy on the validation set is improved to 68.7866927592955! Model saved to DenseNet169_savedModel.pth
# Validation Loss: 1.227 | Validation accuracy: 68.787%
# ************************************
#
# ========== epoch: [45/50] ==========
# LR is set to 0.004096000000000001
# Epoch [45/50], Step [100/288], Training Loss: 0.7866 | Training accuracy: 78.281%
# Epoch [45/50], Step [200/288], Training Loss: 0.7894 | Training accuracy: 78.141%
# Epoch 45, Training Loss: 0.795 | Training accuracy: 78.098%
# --- cost time: 140.6261s ---
# *************** valid ***************
# Validation Loss: 1.408 | Validation accuracy: 68.591%
# ************************************
#
# ========== epoch: [46/50] ==========
# LR is set to 0.004096000000000001
# Epoch [46/50], Step [100/288], Training Loss: 0.7772 | Training accuracy: 78.531%
# Epoch [46/50], Step [200/288], Training Loss: 0.7632 | Training accuracy: 78.844%
# Epoch 46, Training Loss: 0.772 | Training accuracy: 78.891%
# --- cost time: 140.2012s ---
# *************** valid ***************
# Validation Loss: 1.583 | Validation accuracy: 66.536%
# ************************************
#
# ========== epoch: [47/50] ==========
# LR is set to 0.004096000000000001
# Epoch [47/50], Step [100/288], Training Loss: 0.7182 | Training accuracy: 80.469%
# Epoch [47/50], Step [200/288], Training Loss: 0.7480 | Training accuracy: 79.672%
# Epoch 47, Training Loss: 0.779 | Training accuracy: 78.576%
# --- cost time: 140.6086s ---
# *************** valid ***************
# Validation Loss: 1.302 | Validation accuracy: 66.830%
# ************************************
#
# ========== epoch: [48/50] ==========
# LR is set to 0.004096000000000001
# Epoch [48/50], Step [100/288], Training Loss: 0.7516 | Training accuracy: 79.500%
# Epoch [48/50], Step [200/288], Training Loss: 0.7536 | Training accuracy: 79.094%
# Epoch 48, Training Loss: 0.758 | Training accuracy: 79.185%
# --- cost time: 139.4709s ---
# *************** valid ***************
# Validation Loss: 1.372 | Validation accuracy: 67.906%
# ************************************
#
# ========== epoch: [49/50] ==========
# LR is set to 0.004096000000000001
# Epoch [49/50], Step [100/288], Training Loss: 0.6912 | Training accuracy: 80.938%
# Epoch [49/50], Step [200/288], Training Loss: 0.7267 | Training accuracy: 80.047%
# Epoch 49, Training Loss: 0.744 | Training accuracy: 79.391%
# --- cost time: 139.9699s ---
# *************** valid ***************
# Validation Loss: 1.343 | Validation accuracy: 68.395%
# ************************************
#
# ========== epoch: [50/50] ==========
# LR is set to 0.004096000000000001
# Epoch [50/50], Step [100/288], Training Loss: 0.7617 | Training accuracy: 80.344%
# Epoch [50/50], Step [200/288], Training Loss: 0.7374 | Training accuracy: 80.000%
# Epoch 50, Training Loss: 0.737 | Training accuracy: 79.880%
# --- cost time: 139.0035s ---
# *************** valid ***************
# Validation Loss: 1.313 | Validation accuracy: 67.906%
# ************************************

# %%
# Visualize the change of the accuracy
train_acc_result = []
for record in record_train:
    train_acc_result.append(record.cuda().data.cpu().numpy())

plt.style.use("ggplot")
plt.plot(range(1, len(train_acc_result) + 1), train_acc_result, label="train acc")
if record_valid is not None:
    plt.plot(range(1, len(record_valid) + 1), record_valid, label="valid acc")

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("learning accuracy curve")
plt.xticks(range(0, len(train_acc_result) + 1, 5))
plt.yticks(range(0, 101, 5))
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.show()

# %%
# Visualize the change of the loss
train_loss_result = []
for record in loss_record_train:
    train_loss_result.append(record)

plt.style.use("ggplot")
plt.plot(range(1, len(train_loss_result) + 1), train_loss_result, label="train acc")

valid_loss_result = []
for record in loss_record_valid:
    valid_loss_result.append(record.cuda().data.cpu().numpy())
plt.plot(range(1, len(valid_loss_result) + 1), valid_loss_result, label="valid acc")

plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("learning loss curve")
plt.xticks(range(0, len(train_loss_result) + 1, 5))
plt.yticks(range(0, 10, 1))
plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
